# %% [markdown]
# **Basic python operators**

# %% [markdown]
# ASSIGNMENT OPERATOR

# %% [markdown]
# RELATIONAL OPERATOR

# %% [markdown]
# COMPARISON OPERATOR

# %% [markdown]
# LOGICAL OPERATOR

# %% [markdown]
# ARITHMATIC OPERATOR

# %% [markdown]
# BITWISE OPERATOR

# %% [markdown]
# TERNARY OPERATOR

# %%
num=int(input("enter any  num"))
if num % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# enter any  num 12
# even

# %%
age=int(input("age"))
if age>=18:
    nationality=input("enter your country").lower()
    if nationality  == "india":
        print("eligilbe to vote")
    else:
        print("not eligible")
else:
    print("under age")
# Out:
# age 99
# enter your country SEXPUR
# not eligible
