# %%
import re

# %%
text = "my numm is 7200000535"
result = re.search(r"\d{10}",text)
print(result.group())
# Out:
# 7200000535

# %%
re.findall(r"\d+","abc 12 xyz 45")
# Out:
# ['12', '45']

# %%
number=result.group()
number=int(number)

# %%
type(number)
# Out:
# int

# %%
message="i have got 90 marks in english and 80 marks in math"
marks=re.findall(r"\d+",message)
print(marks)
# Out:
# ['90', '80']

# %%
type(marks)
# Out:
# list

# %%
sum = 0
for i in marks:
    sum = sum+int(i)
print(sum)
# Out:
# 170

# %%
re.sub(r"\d","*",message)
# Out:
# 'i have got ** marks in english and ** marks in math'

# %%
message
# Out:
# 'i have got 90 marks in english and 80 marks in math'

# %%
re.match(r"\d+","123abc456")
# Out:
# <re.Match object; span=(0, 3), match='123'>

# %%
re.split(r"\s+",message)
# Out:
# ['i',
#  'have',
#  'got',
#  '90',
#  'marks',
#  'in',
#  'english',
#  'and',
#  '80',
#  'marks',
#  'in',
#  'math']
