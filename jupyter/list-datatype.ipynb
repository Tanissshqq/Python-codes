# %%
list=[2,3,4,3,4,'nish']

# %%
print(list)
# Out:
# [2, 3, 4, 3, 4, 'nish']

# %%
list.index(3)
# Out:
# 1

# %%
list[2]='Tanishq'

# %%
print(list)
# Out:
# [2, 3, 'Tanishq', 3, 4, 'nish']

# %%
list.count(3)
# Out:
# 2

# %%
print(list)
# Out:
# [2, 3, 'Tanishq', 3, 4, 'nish']

# %%
list2=[22,444,9,1,44,55,665,100,222]

# %%
list2.sort(reverse=True)

# %%
print(list2)
# Out:
# [665, 444, 222, 100, 55, 44, 22, 9, 1]

# %%
list.remove(3)

# %%
print(list)
# Out:
# [2, 'Tanishq', 3, 4, 'nish']

# %%
list.pop(0)
# Out:
# 2

# %%
list2.pop(4)
# Out:
# 55

# %%
print(list2)
# Out:
# [665, 444, 222, 100, 44, 22, 9, 1]

# %%
list2.extend(list)

# %%
print(list2)
# Out:
# [665, 444, 222, 100, 44, 22, 9, 1, 'Tanishq', 'nish']

# %%
print(list)
# Out:
# ['Tanishq', 'nish']

# %%
list2.insert(3,list)

# %%
print(list2)
# Out:
# [665, 444, 222, ['Tanishq', 'nish'], 100, 44, 22, 9, 1, 'Tanishq', 'nish']

# %%
print(list2[3][0:2])
# Out:
# ['Tanishq', 'nish']

# %%
name='chaman'

# %%
list2.append(name)

# %%
list2
# Out:
# [665,
#  444,
#  222,
#  ['Tanishq', 'nish'],
#  100,
#  44,
#  22,
#  9,
#  1,
#  'Tanishq',
#  'nish',
#  'chaman']
