# %% [markdown]
# **File handlinG**

# %%
file = open('cgc.text','w')
file.write('cgc aaleo paa deo rola')
# Out:
# 22

# %%
file.close()

# %%
file=open('cgc.text','w')
file.write('i am in cgc')
file.close()

# %%
file=open('new_cgc.text','w')
file.write('i am in cgc landran')
file.close()

# %%
file=open('new_cgc.text','r')
r=file.read()
file.close()

# %%
print(r)
# Out:
# i am in cgc landran

# %%
file=open('cgc.text','a')
file.write('\n this is line 2')
# Out:
# 16

# %%
file.close()

# %%
with open('cgc.text','a') as f:
    a=int(input('number of line'))
    for i in range(a):
        data = input()
        f.write(data + '\n')
# Out:
# number of life 2
#  hi
#  bye

# %%
with open('cgc.text','r') as f: 
    new_content=f.read()
    print(f.read())
    print(new_content)
# Out:
# i am in cgc landran
#  this is line 2
#  this is line 2hi/
# hlo/
# bye/
# hi
# bye
