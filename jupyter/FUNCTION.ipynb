# %% [markdown]
# **FUNCTION IN PYTHON**

# %%
a = "my name is tanishq"

# %%
type(a)
# Out:
# str

# %%
b = 5

# %%
type(b)
# Out:
# int

# %%
c = "5"
type(c)
# Out:
# str

# %%
fl = 45.5

# %%
type(fl)
# Out:
# float
