# %%
age = int(input('ENTER YOUR AGE : '))

if age < 18:
    print('under age')
if age == 18:
   print('currently adult')
# Out:
# ENTER YOUR AGE :  18
# currently adult

# %%
num = int(input('enter number'))
if num<9 :
    print('one digit num')
elif (num>9<99):
    print('two digit')
# Out:
# enter number 66
# two digit

# %%
number= int(input('enter number'))
if number==10:
    print('there are 10 people eligble for the gift')
else:
    print('not enough gifts')
# Out:
# enter number 56
# not enough gifts

# %%
num= int(input('enter number'))
if (1<num<9):
    print('one digit')
elif (10<num <99):
    print('two digit')
elif (100<num <999):
     print('three digit')
# Out:
# enter number 540
# three digit

# %%
age= int(input('enter your age'))
if age  < 18:
   print('underage')
if age == 18:
   print('newly adult')
