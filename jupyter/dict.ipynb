# %% [markdown]
# #dictionary

# %%
student={'name':'Tanishq' , 'age':'20'}

# %%
print(student)
# Out:
# {'name': 'Tanishq', 'age': '20'}

# %%
student['address']='ambala'

# %%
print(student)
# Out:
# {'name': 'Tanishq', 'age': '20', 'address': 'ambala'}

# %%
 print(student.get('name','value not found'))
# Out:
# Tanishq

# %%
students={
    'student1':{
        'roll num':2255,
        'name':'chaddi'
    },
    'student2':{
        'name':'phenle',
        'roll num':2323
    }
}

# %%
print(students['student1']['name'])
# Out:
# chaddi

# %%
print(students.items())
# Out:
# dict_items([('student1', {'roll num': 2255, 'name': 'chaddi'}), ('student2', {'name': 'phenle', 'roll num': 2323})])
