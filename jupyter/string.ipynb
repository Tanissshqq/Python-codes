# %% [markdown]
# #string

# %%
name='tanishq'

# %%
name.upper()
# Out:
# 'TANISHQ'

# %%
sentence = "fuck you bitch"

# %%
sentence.split()
# Out:
# ['fuck', 'you', 'bitch']

# %%
print("--".join(sentence))
# Out:
# f--u--c--k-- --y--o--u-- --b--i--t--c--h
